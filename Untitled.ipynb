# %%
import pandas as pd

# %%
data_df = pd.read_csv('JC-202007-citibike-tripdata.csv')
data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1              1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2               786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3              1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4              2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...             ...                       ...                       ...
# 38675          1003  2020-07-31 23:51:37.3790  2020-08-01 00:08:20.6900
# 38676           165  2020-07-31 23:56:33.6770  2020-07-31 23:59:18.8610
# 38677           382  2020-07-31 23:56:55.9860  2020-08-01 00:03:18.8390
# 38678           674  2020-07-31 23:57:58.0150  2020-08-01 00:09:12.0420
# 38679          1007  2020-07-31 23:58:06.3070  2020-08-01 00:14:53.3340
#
#        start station id          start station name  start station latitude  \
# ...

# %%
data_df['bikeid'].nunique()
# Out:
# 630

# %%
bikes_df = data[['bikeid']]
bikes
# Out:
#        bikeid
# 0       42579
# 1       42564
# 2       42219
# 3       44424
# 4       42186
# ...       ...
# 38675   42145
# 38676   44334
# 38677   42154
# 38678   45366
# 38679   42139
#
# [38680 rows x 1 columns]

# %%
unique_bikes = bikes.bikeid.unique()
unique_bikes
# Out:
# array([42579, 42564, 42219, 44424, 42186, 42446, 44415, 44225, 20748,
#        42258, 44403, 42363, 42336, 42329, 44420, 42431, 42174, 42601,
#        42162, 42126, 42197, 42396, 42499, 39066, 42237, 44348, 42331,
#        44389, 44426, 42493, 21500, 42417, 42494, 42334, 42438, 42293,
#        42634, 42195, 42348, 42125, 41498, 44223, 42180, 42436, 42212,
#        42242, 42468, 42457, 42973, 42420, 42244, 42489, 42435, 42143,
#        42226, 42470, 42133, 42486, 38937, 42141, 44254, 42609, 42542,
#        28205, 42463, 42270, 44280, 42298, 42142, 42280, 42164, 42310,
#        42376, 42346, 42629, 44343, 42444, 44380, 44339, 44492, 17123,
#        40436, 44401, 42453, 29855, 42224, 44336, 44370, 42419, 42456,
#        42202, 42183, 42205, 27576, 42427, 42138, 44407, 42275, 44373,
#        42596, 42448, 44413, 44543, 41289, 42332, 42605, 44235, 42573,
#        42432, 44394, 44425, 42191, 40910, 44340, 44345, 42128, 19153,
# ...

# %%
unique_bikes_df = pd.DataFrame(columns = ['unique_bike_ID'])
unique_bikes_df
# Out:
# Empty DataFrame
# Columns: [unique_bike_ID]
# Index: []

# %%
for bike in unique_bikes:
    unique_bikes_df.append({'unique_bike_ID': bike}, ignore_index=True)

unique_bikes_df
# Out:
# Empty DataFrame
# Columns: [unique_bike_ID]
# Index: []

# %%
bike_occurrence = pd.DataFrame(columns = ['bikeID', 'Occurrence#'])
bike_occurrence
for bike in bikes:
    bike_occurrence.append({'bike'})
# Out:
# Empty DataFrame
# Columns: [bikeID, Occurrence#]
# Index: []

# %%
"I want to have a list of each bike with their number of occurences then sort by decending number of occurences"

# %%
# Out:
# bikeid    38680
# dtype: int64

# %%
df = pd.DataFrame(columns=['A'])
for i in range(5):
    df = df.append({'A': i}, ignore_index=True)
df
   A
0  0
1  1
2  2
3  3
4  4
